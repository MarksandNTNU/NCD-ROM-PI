# %%
from scipy.io import loadmat

data = loadmat('CF_summary_data.mat')
display(data)
print(data.keys())
# Skip MATLAB metadata keys
for k, v in data.items():
    if not k.startswith('__'):
        print(f"{k}: shape={v.shape if hasattr(v, 'shape') else type(v)}")
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Fri Apr 24 23:16:27 2026',
#  '__version__': '1.0',
#  '__globals__': [],
#  'Do': array([[0.027]]),
#  'E': array([[3.62e+10]]),
#  'EA': array([[509000]], dtype=int32),
#  'EI': array([[37.2]]),
#  'Fs': array([[1200]], dtype=uint16),
#  'K0': array([[2.34422882e-12]]),
#  'L': array([[38]], dtype=uint8),
#  'U_all': array([[0.29803401, 0.39717907, 0.49649843, 0.59590436, 0.69503995,
#          0.7938957 , 0.8925832 , 0.99201685, 1.0912074 , 1.19012961,
#          1.28870896, 1.38815071, 1.48695058, 1.58379194, 1.68194321,
#          1.77745842, 1.87400088, 1.97313354, 2.07589691, 2.17410724,
#          2.27215065, 2.37328752, 0.27212909, 0.36294026, 0.4539642 ,
#          0.54541918, 0.63687862, 0.72866202, 0.82055439, 0.91223369,
#          1.0051875 , 1.09839981, 1.19298971, 1.28984187, 1.38200101,
#          1.47355862, 1.5707053 , 1.65347828, 1.75330949, 1.85636126,
# ...
